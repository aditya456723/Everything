# %%
#find out Node whose children are 45 and 55

class newNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
def insert(root, data):
    if root == None:
        return newNode(data)
    if data < root.data:
        root.left = insert(root.left, data)
    elif data > root.data:
        root.right = insert(root.right, data)
    return root

def search(root):
        if root==None:
            print()
            print("element not found")
            return None
        if (root.right!=None or root.left!=None) :
            if ((root.right.data==45 and root.left.data==55)):
                print("nodes were found for the root",root.data)
            root.right=search(root.right)
            root.left=search(root.left)

            
root= newNode(100)
insert(root,50)
insert(root,55)
insert(root,45)
insert(root,155)
insert(root,145)
insert(root,160)
search(root)
# Out:
# nodes were found for the root 50

# %%
#delete parent

class newNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insert(root, data):
    if root == None:
        return newNode(data)
    if data < root.data:
        root.left = insert(root.left, data)
    elif data > root.data:
        root.right = insert(root.right, data)
    return root
       
def inorder(root):
    if root != None:
        inorder(root.left)
        print(root.data, end = " ")  
        inorder(root.right)

def delete(root,data):
    if root is None:
        return root
    if data < root.data:
        root.left = delete(root.left, data)
    elif(data > root.data):
        root.right = delete(root.right,data)
    else:
        if root.left is None:
            temp = root.right
            root = None
            return temp
        elif root.right is None:
            temp = root.left
            root = None
            return temp
        temp = minValueNode(root.right)
        root.data = temp.data
        root.right = delete(root.right, temp.data)
    return root

def minValueNode(node):
    current = node
    while(current.left is not None):
        current = current.left
    delete(current,current.data)
    
def search(root,data):
        if root==None:
            print()
            print("element not found")
            return None
        if root.right and root.right.data == data:
            return delete(root,root.data)
        if root.left and root.left.data==data :
            return delete(root,root.data)
        if root.data < data:
            root.right=search(root.right,data)
        else :
            root.left=search(root.left,data)
        return root

root= newNode(1)
root=insert(root,2)
root=insert(root,3)
root=insert(root,4)
root=insert(root,5)
root=insert(root,6)
root=insert(root,7)
root=insert(root,8)

inorder(root)
root=search(root,2)
print("\n")
inorder(root)
# Out:
# 1 2 3 4 5 6 7 8
#
# 2 3 4 5 6 7 8

# %%
#find node whose height is 5

class newNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
def insert(root, data):
    if root == None:
        return newNode(data)
    if data < root.data:
        root.left = insert(root.left, data)
    elif data > root.data:
        root.right = insert(root.right, data)
    return root

def height(root):
    if root is None:
        return 0
    leftAns = height(root.left)
    rightAns = height(root.right)
    return max(leftAns, rightAns) + 1

def heightsearch(root):
    if root != None:
        if height(root)==5 :
            print("the node with height 5 is",root.data)
        heightsearch(root.left)
        heightsearch(root.right)

root= newNode(1)
insert(root,2)
insert(root,3)
insert(root,4)
insert(root,5)
insert(root,6)
insert(root,7)
insert(root,8)


heightsearch(root)

# %%
#delete child node of a given node

class Node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None
        
def insertion(root,data):
    if root==None:
        return Node(data)
    if data<root.data:
        root.left=insertion(root.left,data)
    else:
        root.right=insertion(root.right,data)
    return root

def preorder(root):
    if root!=None:
        print(root.data,end = " ")
        preorder(root.left)
        preorder(root.right)
        
def search_of_node(root,data):
    if root.data==data:
        tem=root
        if tem.right is None and tem.left is None:
            return tem
        if tem.right is not None and tem.left is not None: 
            return deletionNode(root,tem.left.data)
        elif tem.left is None:
            return deletionNode(root,tem.right.data)
        elif root.right is None:
            return deletionNode(root,tem.left.data) 
    if data<root.data:
         return search_of_node(root.left,data)
    else:
        return search_of_node(root.right,data)
    
def deletionNode(root,data):
    #Base Case
    if root is None:
        return root
    if data < root.data:
        root.left=deletionNode(root.left,data)
    elif data > root.data:
        root.right=deletionNode(root.right,data)
    #TWO CHILDS
    else:
        if root.left is not None and root.right is not None:
            temp=inordersucc(root.right)
            root.data=temp.data
            #deleting the inorder successor
            root.right=deletionNode(root.right,temp.data)
        #Single or No Child
        if root.left is None and root.right is None:
            root=None
            return root
        elif root.left is None:
            temp=root.right
            root=None
            return temp
        elif root.right is None:
            temp=root.left
            root=None
            return temp
    return root

def inordersucc(root):
    #Right Part Left Most Node
    current=root
    while current.left is not None:
        current=current.left
    return current

def inorderpred(root):
    current=root
    while current.right is not None:
        current=current.right
    return current

root=None
a=[50,30,70,20,40,60,80]
for i in a:
    root=insertion(root,i)
preorder(root)
search_of_node(root,50)

print("\n")

print("AFTER DELETING")
preorder(root)
# Out:
# 50 30 20 40 70 60 80
#
# AFTER DELETING
# 50 20 70 60 80
